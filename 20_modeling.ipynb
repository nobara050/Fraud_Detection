# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%capture
# !pip install torch_geometric

# %%
import os
cur_path = "/content/drive/MyDrive/gfd_ver2/"
os.chdir(cur_path)
# !pwd
# Out:
# /content/drive/MyDrive/gfd_ver2

# %%
# !python train.py --n-epochs 1000
# Out:
# PyTorch Geometric version: 2.7.0
# numpy version:2.0.2 PyTorch version:2.10.0+cu128 PyG version:2.7.0
# Namespace(training_dir='./data', model_dir='./model/final', output_dir='./output', nodes='features.csv', target_ntype='TransactionID', edges='relation*', labels='tags.csv', new_accounts='test.csv', compute_metrics=True, threshold=0, num_gpus=1, optimizer='adam', lr=0.01, n_epochs=1000, n_hidden=16, n_layers=3, weight_decay=0.0005, dropout=0.2, embedding_size=360)
# Using GPU: 0 - Tesla T4
# ...
